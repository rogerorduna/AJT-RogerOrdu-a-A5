# %% [markdown]
# exercici 1

# %%
class song: 
    def __init__(self, titol, autor, durada):
        self.titol=titol 
        self.autor=autor
        self.durada=durada 
    def info(self):
        return f"{self.titol}-{self.autor}-({self.durada})"
    song1=song("pitinho","cotoner","115")
    song1.info()

class playlist(): 
    def __init__(self,songlist):
        self.song_list=()
        def afegir_canco(song):
            song_list.appened(canco_afegida)
            def durada_total():
                for song() in song_list:
                    durada_total=0
                    for song in song_list:
                        durada_total=durada_total+self.durada
canco_afegida=song(imput)
# Out:
#   Cell In[10], line 17
#     for song() in song_list:
#         ^
# SyntaxError: cannot assign to function call

# %%
class personantge():
    def __init__(self,nom,vida,força,nivell):
        self.nom=nom
        self.vida=vida
        self.força=força
        self.nivell=nivell
    def atacar(self,enemic):
        enemic.vida=enemic.vida-self.força

def pujar_nivell(personatg):
    self.vida=self.vida+1
    self.força=self.força+5
    self.nivell=self.nivell+1

def esta_viu(self,vida):
   if self.vida>0:
    if True:
    def _str_(self):
    return f"Nom: {self.nom} Vida: {self.vida}\ Força: {self.força} Nivell: {self.nivell}"

jugador=personatge("jugador1" ,10,2,1)
enemic =personatge("enemic" ,4,3,1)

def combat(self):
while jugador.vida or enemic_vida>0
    jugador.atacar(enemic, jugador)
    enemic.atacar(jugador,enemic)
    if jugador.vida<=0
        print("el jugador a guanyat")
        jugador.pujar_nivell
# Out:
#   Cell In[20], line 18
#     def _str_(self):
#     ^
# IndentationError: expected an indented block after 'if' statement on line 17
